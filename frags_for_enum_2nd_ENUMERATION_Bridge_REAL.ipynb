# %%
import os
from rdkit import Chem

def modify_atoms(mol):
    if not mol:
        return None
    
    for atom in mol.GetAtoms():
        if atom.HasProp('molAtomMapNumber'):
            map_num = atom.GetProp('molAtomMapNumber')
            if map_num in {'1', '2', '3'}:
                atom.SetProp('molAtomMapNumber', '0')
        if atom.GetIsotope() != 0:
            atom.SetIsotope(0)

    return mol

def process_sdf_file(file_path):
    # Read the SDF file
    suppl = Chem.SDMolSupplier(file_path, removeHs=False)
    mols = [mol for mol in suppl if mol is not None]

    # Process each molecule
    processed_mols = [modify_atoms(mol) for mol in mols if mol]

    # Write the processed molecules back to a new SDF file
    output_file = file_path.replace(".sdf", "_processed.sdf")
    writer = Chem.SDWriter(output_file)
    for mol in processed_mols:
        writer.write(mol)
    writer.close()

    # Print out the message indicating the file has been processed
    print(f"File {file_path} has been processed and saved as {output_file}")

# Specific SDF file to process
file_to_process = "BKVP1_Ac_APF_v2_Ac_bridge.sdf"

# Check if the file exists in the current directory
if os.path.exists(file_to_process):
    process_sdf_file(file_to_process)
else:
    print(f"The file {file_to_process} does not exist in the current directory.")

print("Processing complete.")
# Out:
# File BKVP1_Ac_APF_v2_Ac_bridge.sdf has been processed and saved as BKVP1_Ac_APF_v2_Ac_bridge_processed.sdf
# Processing complete.

# %%
import os
import gc  # Import garbage collection module
from rdkit import Chem
from rdkit.Chem import rdFMCS
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

def load_molecules(file_path, start_index, batch_size=None):
    """Load a batch of molecules from an SDF file starting from a given index."""
    logging.info(f"Loading molecules from {file_path} starting at index {start_index}")
    suppl = Chem.SDMolSupplier(file_path, removeHs=False)
    mols = []

    # Skip molecules up to the start index
    for i, mol in enumerate(suppl):
        if i < start_index:
            continue
        if mol is not None:
            mols.append(mol)
        if batch_size is not None and len(mols) >= batch_size:  # Check batch_size only if it is not None
            break

    logging.info(f"Loaded {len(mols)} molecules starting from index {start_index}")
    return mols

def calculate_substructure_similarity(mol, fragment):
    """Calculate the similarity between a molecule and a fragment."""
    try:
        mcs_result = rdFMCS.FindMCS([mol, fragment], completeRingsOnly=True, ringMatchesRingOnly=True)
        if mcs_result.canceled:
            return 0.0
        mcs = Chem.MolFromSmarts(mcs_result.smartsString)
        if mcs is not None:
            common_atoms = mcs.GetNumHeavyAtoms()
            total_atoms = mol.GetNumHeavyAtoms() + fragment.GetNumHeavyAtoms() - common_atoms
            similarity = common_atoms / total_atoms if total_atoms > 0 else 0.0
            return similarity
        else:
            return 0.0
    except Exception as e:
        logging.error(f"Error in calculating substructure similarity: {e}")
        return 0.0

def find_best_fragment(molecule, fragments):
    """Find the most similar fragment to the given molecule and return its index and similarity."""
    best_similarity = -1
    best_index = -1

    for index, fragment in enumerate(fragments):
        similarity = calculate_substructure_similarity(molecule, fragment)
        if similarity > best_similarity:
            best_similarity = similarity
            best_index = index + 1  # 1-based index

    return best_index, best_similarity

def main():
    fragment_file = "R284_Ac.sdf"
    large_file = "BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf"
    output_file = "BKVP1_with_frag_similarity.sdf"
    batch_size = 1000  # Process molecules in batches of 1000
    total_molecules = 75497

    logging.info("Loading fragments...")
    fragments = load_molecules(fragment_file, start_index=0, batch_size=None)
    logging.info(f"Loaded {len(fragments)} fragments.")

    # Initialize the writer
    writer = Chem.SDWriter(output_file)

    # Process molecules in batches, keeping track of the start index
    for start_index in range(0, total_molecules, batch_size):
        logging.info(f"Processing batch starting from index {start_index}...")

        # Load a batch of molecules starting from the current index
        large_mols = load_molecules(large_file, start_index=start_index, batch_size=batch_size)

        for i, mol in enumerate(large_mols):
            best_index, best_similarity = find_best_fragment(mol, fragments)

            # Set the properties for the molecule
            mol.SetProp("BestFragmentIndex", str(best_index))
            mol.SetProp("MaxSimilarity", f"{best_similarity:.4f}")

            # Write the updated molecule to the output file
            writer.write(mol)

            if (start_index + i + 1) % 1000 == 0:
                logging.info(f"Processed {start_index + i + 1}/{total_molecules} molecules.")

        # Force garbage collection to free memory
        del large_mols
        gc.collect()

    logging.info("Processing complete. Output written to file.")
    writer.close()

if __name__ == "__main__":
    main()
# Out:
# 2024-09-23 10:26:04,450 - Loading fragments...
# 2024-09-23 10:26:04,451 - Loading molecules from R284_Ac.sdf starting at index 0
# 2024-09-23 10:26:04,456 - Loaded 4 molecules starting from index 0
# 2024-09-23 10:26:04,458 - Loaded 4 fragments.
# 2024-09-23 10:26:04,552 - Processing batch starting from index 0...
# 2024-09-23 10:26:04,553 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 0
# 2024-09-23 10:26:05,310 - Loaded 1000 molecules starting from index 0
# 2024-09-23 10:32:09,069 - Processed 1000/75497 molecules.
# 2024-09-23 10:32:19,375 - Processing batch starting from index 1000...
# 2024-09-23 10:32:19,376 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 1000
# 2024-09-23 10:32:20,640 - Loaded 1000 molecules starting from index 1000
# 2024-09-23 10:39:20,864 - Processed 2000/75497 molecules.
# 2024-09-23 10:39:20,964 - Processing batch starting from index 2000...
# 2024-09-23 10:39:20,965 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 2000
# 2024-09-23 10:39:22,827 - Loaded 1000 molecules starting from index 2000
# 2024-09-23 10:44:09,252 - Processed 3000/75497 molecules.
# 2024-09-23 10:44:09,343 - Processing batch starting from index 3000...
# 2024-09-23 10:44:09,345 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 3000
# 2024-09-23 10:44:11,826 - Loaded 1000 molecules starting from index 3000
# 2024-09-23 10:46:36,988 - Processed 4000/75497 molecules.
# 2024-09-23 10:46:37,069 - Processing batch starting from index 4000...
# 2024-09-23 10:46:37,070 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 4000
# 2024-09-23 10:46:40,412 - Loaded 1000 molecules starting from index 4000
# 2024-09-23 10:48:37,729 - Processed 5000/75497 molecules.
# 2024-09-23 10:48:37,799 - Processing batch starting from index 5000...
# 2024-09-23 10:48:37,800 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 5000
# 2024-09-23 10:48:41,465 - Loaded 1000 molecules starting from index 5000
# 2024-09-23 10:50:12,223 - Processed 6000/75497 molecules.
# 2024-09-23 10:50:12,297 - Processing batch starting from index 6000...
# 2024-09-23 10:50:12,298 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 6000
# 2024-09-23 10:50:16,548 - Loaded 1000 molecules starting from index 6000
# 2024-09-23 10:51:38,697 - Processed 7000/75497 molecules.
# 2024-09-23 10:51:38,768 - Processing batch starting from index 7000...
# 2024-09-23 10:51:38,769 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 7000
# 2024-09-23 10:51:43,572 - Loaded 1000 molecules starting from index 7000
# 2024-09-23 10:53:08,792 - Processed 8000/75497 molecules.
# 2024-09-23 10:53:08,864 - Processing batch starting from index 8000...
# 2024-09-23 10:53:08,865 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 8000
# 2024-09-23 10:53:14,303 - Loaded 1000 molecules starting from index 8000
# 2024-09-23 10:54:35,818 - Processed 9000/75497 molecules.
# 2024-09-23 10:54:35,890 - Processing batch starting from index 9000...
# 2024-09-23 10:54:35,891 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 9000
# 2024-09-23 10:54:41,894 - Loaded 1000 molecules starting from index 9000
# 2024-09-23 10:55:53,918 - Processed 10000/75497 molecules.
# 2024-09-23 10:55:54,005 - Processing batch starting from index 10000...
# 2024-09-23 10:55:54,007 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 10000
# 2024-09-23 10:56:00,662 - Loaded 1000 molecules starting from index 10000
# 2024-09-23 10:57:21,714 - Processed 11000/75497 molecules.
# 2024-09-23 10:57:21,783 - Processing batch starting from index 11000...
# 2024-09-23 10:57:21,785 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 11000
# 2024-09-23 10:57:28,936 - Loaded 1000 molecules starting from index 11000
# 2024-09-23 10:58:36,311 - Processed 12000/75497 molecules.
# 2024-09-23 10:58:36,379 - Processing batch starting from index 12000...
# 2024-09-23 10:58:36,381 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 12000
# 2024-09-23 10:58:44,180 - Loaded 1000 molecules starting from index 12000
# 2024-09-23 11:00:06,918 - Processed 13000/75497 molecules.
# 2024-09-23 11:00:06,987 - Processing batch starting from index 13000...
# 2024-09-23 11:00:06,988 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 13000
# 2024-09-23 11:00:15,332 - Loaded 1000 molecules starting from index 13000
# 2024-09-23 11:01:24,825 - Processed 14000/75497 molecules.
# 2024-09-23 11:01:24,895 - Processing batch starting from index 14000...
# 2024-09-23 11:01:24,896 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 14000
# 2024-09-23 11:01:33,835 - Loaded 1000 molecules starting from index 14000
# 2024-09-23 11:02:36,745 - Processed 15000/75497 molecules.
# 2024-09-23 11:02:36,816 - Processing batch starting from index 15000...
# 2024-09-23 11:02:36,817 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 15000
# 2024-09-23 11:02:46,358 - Loaded 1000 molecules starting from index 15000
# 2024-09-23 11:03:49,346 - Processed 16000/75497 molecules.
# 2024-09-23 11:03:49,413 - Processing batch starting from index 16000...
# 2024-09-23 11:03:49,414 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 16000
# 2024-09-23 11:03:59,487 - Loaded 1000 molecules starting from index 16000
# 2024-09-23 11:05:06,186 - Processed 17000/75497 molecules.
# 2024-09-23 11:05:06,254 - Processing batch starting from index 17000...
# 2024-09-23 11:05:06,255 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 17000
# 2024-09-23 11:05:16,949 - Loaded 1000 molecules starting from index 17000
# 2024-09-23 11:06:20,660 - Processed 18000/75497 molecules.
# 2024-09-23 11:06:20,728 - Processing batch starting from index 18000...
# 2024-09-23 11:06:20,729 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 18000
# 2024-09-23 11:06:32,018 - Loaded 1000 molecules starting from index 18000
# 2024-09-23 11:07:40,309 - Processed 19000/75497 molecules.
# 2024-09-23 11:07:40,392 - Processing batch starting from index 19000...
# 2024-09-23 11:07:40,393 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 19000
# 2024-09-23 11:07:52,193 - Loaded 1000 molecules starting from index 19000
# 2024-09-23 11:09:00,992 - Processed 20000/75497 molecules.
# 2024-09-23 11:09:01,061 - Processing batch starting from index 20000...
# 2024-09-23 11:09:01,062 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 20000
# 2024-09-23 11:09:13,590 - Loaded 1000 molecules starting from index 20000
# 2024-09-23 11:10:19,101 - Processed 21000/75497 molecules.
# 2024-09-23 11:10:19,168 - Processing batch starting from index 21000...
# 2024-09-23 11:10:19,169 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 21000
# 2024-09-23 11:10:32,166 - Loaded 1000 molecules starting from index 21000
# 2024-09-23 11:11:35,986 - Processed 22000/75497 molecules.
# 2024-09-23 11:11:36,052 - Processing batch starting from index 22000...
# 2024-09-23 11:11:36,053 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 22000
# 2024-09-23 11:11:49,656 - Loaded 1000 molecules starting from index 22000
# 2024-09-23 11:12:53,372 - Processed 23000/75497 molecules.
# 2024-09-23 11:12:53,450 - Processing batch starting from index 23000...
# 2024-09-23 11:12:53,451 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 23000
# 2024-09-23 11:13:08,030 - Loaded 1000 molecules starting from index 23000
# 2024-09-23 11:14:12,209 - Processed 24000/75497 molecules.
# 2024-09-23 11:14:12,275 - Processing batch starting from index 24000...
# 2024-09-23 11:14:12,276 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 24000
# 2024-09-23 11:14:26,935 - Loaded 1000 molecules starting from index 24000
# 2024-09-23 11:15:28,633 - Processed 25000/75497 molecules.
# 2024-09-23 11:15:28,702 - Processing batch starting from index 25000...
# 2024-09-23 11:15:28,703 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 25000
# 2024-09-23 11:15:44,005 - Loaded 1000 molecules starting from index 25000
# 2024-09-23 11:16:50,630 - Processed 26000/75497 molecules.
# 2024-09-23 11:16:50,709 - Processing batch starting from index 26000...
# 2024-09-23 11:16:50,711 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 26000
# 2024-09-23 11:17:06,591 - Loaded 1000 molecules starting from index 26000
# 2024-09-23 11:18:12,568 - Processed 27000/75497 molecules.
# 2024-09-23 11:18:12,638 - Processing batch starting from index 27000...
# 2024-09-23 11:18:12,639 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 27000
# 2024-09-23 11:18:29,050 - Loaded 1000 molecules starting from index 27000
# 2024-09-23 11:19:38,031 - Processed 28000/75497 molecules.
# 2024-09-23 11:19:38,126 - Processing batch starting from index 28000...
# 2024-09-23 11:19:38,127 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 28000
# 2024-09-23 11:19:55,611 - Loaded 1000 molecules starting from index 28000
# 2024-09-23 11:21:04,205 - Processed 29000/75497 molecules.
# 2024-09-23 11:21:04,278 - Processing batch starting from index 29000...
# 2024-09-23 11:21:04,279 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 29000
# 2024-09-23 11:21:21,866 - Loaded 1000 molecules starting from index 29000
# 2024-09-23 11:22:23,253 - Processed 30000/75497 molecules.
# 2024-09-23 11:22:23,324 - Processing batch starting from index 30000...
# 2024-09-23 11:22:23,325 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 30000
# 2024-09-23 11:22:41,910 - Loaded 1000 molecules starting from index 30000
# 2024-09-23 11:23:47,338 - Processed 31000/75497 molecules.
# 2024-09-23 11:23:47,408 - Processing batch starting from index 31000...
# 2024-09-23 11:23:47,409 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 31000
# 2024-09-23 11:24:06,268 - Loaded 1000 molecules starting from index 31000
# 2024-09-23 11:25:13,274 - Processed 32000/75497 molecules.
# 2024-09-23 11:25:13,366 - Processing batch starting from index 32000...
# 2024-09-23 11:25:13,367 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 32000
# 2024-09-23 11:25:32,749 - Loaded 1000 molecules starting from index 32000
# 2024-09-23 11:26:46,937 - Processed 33000/75497 molecules.
# 2024-09-23 11:26:47,009 - Processing batch starting from index 33000...
# 2024-09-23 11:26:47,010 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 33000
# 2024-09-23 11:27:08,019 - Loaded 1000 molecules starting from index 33000
# 2024-09-23 11:28:13,687 - Processed 34000/75497 molecules.
# 2024-09-23 11:28:13,757 - Processing batch starting from index 34000...
# 2024-09-23 11:28:13,758 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 34000
# 2024-09-23 11:28:34,067 - Loaded 1000 molecules starting from index 34000
# 2024-09-23 11:29:45,596 - Processed 35000/75497 molecules.
# 2024-09-23 11:29:45,666 - Processing batch starting from index 35000...
# 2024-09-23 11:29:45,668 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 35000
# 2024-09-23 11:30:06,774 - Loaded 1000 molecules starting from index 35000
# 2024-09-23 11:31:11,638 - Processed 36000/75497 molecules.
# 2024-09-23 11:31:11,710 - Processing batch starting from index 36000...
# 2024-09-23 11:31:11,711 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 36000
# 2024-09-23 11:31:33,356 - Loaded 1000 molecules starting from index 36000
# 2024-09-23 11:32:59,694 - Processed 37000/75497 molecules.
# 2024-09-23 11:32:59,766 - Processing batch starting from index 37000...
# 2024-09-23 11:32:59,767 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 37000
# 2024-09-23 11:33:21,959 - Loaded 1000 molecules starting from index 37000
# 2024-09-23 11:34:33,584 - Processed 38000/75497 molecules.
# 2024-09-23 11:34:33,656 - Processing batch starting from index 38000...
# 2024-09-23 11:34:33,657 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 38000
# 2024-09-23 11:34:56,320 - Loaded 1000 molecules starting from index 38000
# 2024-09-23 11:36:04,493 - Processed 39000/75497 molecules.
# 2024-09-23 11:36:04,580 - Processing batch starting from index 39000...
# 2024-09-23 11:36:04,581 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 39000
# 2024-09-23 11:36:28,010 - Loaded 1000 molecules starting from index 39000
# 2024-09-23 11:37:37,373 - Processed 40000/75497 molecules.
# 2024-09-23 11:37:37,461 - Processing batch starting from index 40000...
# 2024-09-23 11:37:37,462 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 40000
# 2024-09-23 11:38:01,543 - Loaded 1000 molecules starting from index 40000
# 2024-09-23 11:39:00,181 - Processed 41000/75497 molecules.
# 2024-09-23 11:39:00,250 - Processing batch starting from index 41000...
# 2024-09-23 11:39:00,251 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 41000
# 2024-09-23 11:39:26,308 - Loaded 1000 molecules starting from index 41000
# 2024-09-23 11:40:23,613 - Processed 42000/75497 molecules.
# 2024-09-23 11:40:23,684 - Processing batch starting from index 42000...
# 2024-09-23 11:40:23,685 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 42000
# 2024-09-23 11:40:48,825 - Loaded 1000 molecules starting from index 42000
# 2024-09-23 11:41:59,000 - Processed 43000/75497 molecules.
# 2024-09-23 11:41:59,071 - Processing batch starting from index 43000...
# 2024-09-23 11:41:59,073 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 43000
# 2024-09-23 11:42:25,101 - Loaded 1000 molecules starting from index 43000
# 2024-09-23 11:43:32,266 - Processed 44000/75497 molecules.
# 2024-09-23 11:43:32,338 - Processing batch starting from index 44000...
# 2024-09-23 11:43:32,339 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 44000
# 2024-09-23 11:43:58,495 - Loaded 1000 molecules starting from index 44000
# 2024-09-23 11:45:12,479 - Processed 45000/75497 molecules.
# 2024-09-23 11:45:12,550 - Processing batch starting from index 45000...
# 2024-09-23 11:45:12,551 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 45000
# 2024-09-23 11:45:39,266 - Loaded 1000 molecules starting from index 45000
# 2024-09-23 11:46:43,964 - Processed 46000/75497 molecules.
# 2024-09-23 11:46:44,034 - Processing batch starting from index 46000...
# 2024-09-23 11:46:44,035 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 46000
# 2024-09-23 11:47:11,432 - Loaded 1000 molecules starting from index 46000
# 2024-09-23 11:48:27,869 - Processed 47000/75497 molecules.
# 2024-09-23 11:48:27,959 - Processing batch starting from index 47000...
# 2024-09-23 11:48:27,960 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 47000
# 2024-09-23 11:48:56,248 - Loaded 1000 molecules starting from index 47000
# 2024-09-23 11:50:12,435 - Processed 48000/75497 molecules.
# 2024-09-23 11:50:12,512 - Processing batch starting from index 48000...
# 2024-09-23 11:50:12,513 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 48000
# 2024-09-23 11:50:41,777 - Loaded 1000 molecules starting from index 48000
# 2024-09-23 11:51:58,518 - Processed 49000/75497 molecules.
# 2024-09-23 11:51:58,587 - Processing batch starting from index 49000...
# 2024-09-23 11:51:58,588 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 49000
# 2024-09-23 11:52:27,933 - Loaded 1000 molecules starting from index 49000
# 2024-09-23 11:53:38,612 - Processed 50000/75497 molecules.
# 2024-09-23 11:53:38,690 - Processing batch starting from index 50000...
# 2024-09-23 11:53:38,691 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 50000
# 2024-09-23 11:54:09,640 - Loaded 1000 molecules starting from index 50000
# 2024-09-23 11:55:25,636 - Processed 51000/75497 molecules.
# 2024-09-23 11:55:25,717 - Processing batch starting from index 51000...
# 2024-09-23 11:55:25,718 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 51000
# 2024-09-23 11:55:57,130 - Loaded 1000 molecules starting from index 51000
# 2024-09-23 11:57:26,574 - Processed 52000/75497 molecules.
# 2024-09-23 11:57:26,647 - Processing batch starting from index 52000...
# 2024-09-23 11:57:26,648 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 52000
# 2024-09-23 11:57:57,670 - Loaded 1000 molecules starting from index 52000
# 2024-09-23 11:59:08,103 - Processed 53000/75497 molecules.
# 2024-09-23 11:59:08,183 - Processing batch starting from index 53000...
# 2024-09-23 11:59:08,184 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 53000
# 2024-09-23 11:59:39,875 - Loaded 1000 molecules starting from index 53000
# 2024-09-23 12:01:05,090 - Processed 54000/75497 molecules.
# 2024-09-23 12:01:05,174 - Processing batch starting from index 54000...
# 2024-09-23 12:01:05,175 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 54000
# 2024-09-23 12:01:38,040 - Loaded 1000 molecules starting from index 54000
# 2024-09-23 12:03:02,161 - Processed 55000/75497 molecules.
# 2024-09-23 12:03:02,237 - Processing batch starting from index 55000...
# 2024-09-23 12:03:02,238 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 55000
# 2024-09-23 12:03:35,338 - Loaded 1000 molecules starting from index 55000
# 2024-09-23 12:04:57,341 - Processed 56000/75497 molecules.
# 2024-09-23 12:04:57,418 - Processing batch starting from index 56000...
# 2024-09-23 12:04:57,419 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 56000
# 2024-09-23 12:05:31,088 - Loaded 1000 molecules starting from index 56000
# 2024-09-23 12:06:46,772 - Processed 57000/75497 molecules.
# 2024-09-23 12:06:46,856 - Processing batch starting from index 57000...
# 2024-09-23 12:06:46,857 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 57000
# 2024-09-23 12:07:21,272 - Loaded 1000 molecules starting from index 57000
# 2024-09-23 12:08:26,920 - Processed 58000/75497 molecules.
# 2024-09-23 12:08:26,997 - Processing batch starting from index 58000...
# 2024-09-23 12:08:26,998 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 58000
# 2024-09-23 12:09:03,711 - Loaded 1000 molecules starting from index 58000
# 2024-09-23 12:10:46,818 - Processed 59000/75497 molecules.
# 2024-09-23 12:10:46,923 - Processing batch starting from index 59000...
# 2024-09-23 12:10:46,924 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 59000
# 2024-09-23 12:11:33,893 - Loaded 1000 molecules starting from index 59000
# 2024-09-23 12:12:37,562 - Processed 60000/75497 molecules.
# 2024-09-23 12:12:37,634 - Processing batch starting from index 60000...
# 2024-09-23 12:12:37,635 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 60000
# 2024-09-23 12:13:13,629 - Loaded 1000 molecules starting from index 60000
# 2024-09-23 12:14:31,967 - Processed 61000/75497 molecules.
# 2024-09-23 12:14:32,039 - Processing batch starting from index 61000...
# 2024-09-23 12:14:32,040 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 61000
# 2024-09-23 12:15:08,053 - Loaded 1000 molecules starting from index 61000
# 2024-09-23 12:16:05,380 - Processed 62000/75497 molecules.
# 2024-09-23 12:16:05,459 - Processing batch starting from index 62000...
# 2024-09-23 12:16:05,460 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 62000
# 2024-09-23 12:16:42,194 - Loaded 1000 molecules starting from index 62000
# 2024-09-23 12:17:43,481 - Processed 63000/75497 molecules.
# 2024-09-23 12:17:43,552 - Processing batch starting from index 63000...
# 2024-09-23 12:17:43,554 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 63000
# 2024-09-23 12:18:20,401 - Loaded 1000 molecules starting from index 63000
# 2024-09-23 12:19:28,202 - Processed 64000/75497 molecules.
# 2024-09-23 12:19:28,292 - Processing batch starting from index 64000...
# 2024-09-23 12:19:28,293 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 64000
# 2024-09-23 12:20:07,422 - Loaded 1000 molecules starting from index 64000
# 2024-09-23 12:21:07,634 - Processed 65000/75497 molecules.
# 2024-09-23 12:21:07,719 - Processing batch starting from index 65000...
# 2024-09-23 12:21:07,721 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 65000
# 2024-09-23 12:21:47,022 - Loaded 1000 molecules starting from index 65000
# 2024-09-23 12:22:49,236 - Processed 66000/75497 molecules.
# 2024-09-23 12:22:49,306 - Processing batch starting from index 66000...
# 2024-09-23 12:22:49,307 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 66000
# 2024-09-23 12:23:29,657 - Loaded 1000 molecules starting from index 66000
# 2024-09-23 12:24:42,841 - Processed 67000/75497 molecules.
# 2024-09-23 12:24:42,917 - Processing batch starting from index 67000...
# 2024-09-23 12:24:42,919 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 67000
# 2024-09-23 12:25:23,059 - Loaded 1000 molecules starting from index 67000
# 2024-09-23 12:26:32,660 - Processed 68000/75497 molecules.
# 2024-09-23 12:26:32,738 - Processing batch starting from index 68000...
# 2024-09-23 12:26:32,739 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 68000
# 2024-09-23 12:27:12,460 - Loaded 1000 molecules starting from index 68000
# 2024-09-23 12:28:15,088 - Processed 69000/75497 molecules.
# 2024-09-23 12:28:15,160 - Processing batch starting from index 69000...
# 2024-09-23 12:28:15,161 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 69000
# 2024-09-23 12:28:55,128 - Loaded 1000 molecules starting from index 69000
# 2024-09-23 12:30:03,475 - Processed 70000/75497 molecules.
# 2024-09-23 12:30:03,546 - Processing batch starting from index 70000...
# 2024-09-23 12:30:03,547 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 70000
# 2024-09-23 12:30:44,464 - Loaded 1000 molecules starting from index 70000
# 2024-09-23 12:31:45,150 - Processed 71000/75497 molecules.
# 2024-09-23 12:31:45,226 - Processing batch starting from index 71000...
# 2024-09-23 12:31:45,227 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 71000
# 2024-09-23 12:32:26,143 - Loaded 1000 molecules starting from index 71000
# 2024-09-23 12:33:22,543 - Processed 72000/75497 molecules.
# 2024-09-23 12:33:22,614 - Processing batch starting from index 72000...
# 2024-09-23 12:33:22,616 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 72000
# 2024-09-23 12:34:06,254 - Loaded 1000 molecules starting from index 72000
# 2024-09-23 12:35:19,080 - Processed 73000/75497 molecules.
# 2024-09-23 12:35:19,150 - Processing batch starting from index 73000...
# 2024-09-23 12:35:19,152 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 73000
# 2024-09-23 12:36:01,776 - Loaded 1000 molecules starting from index 73000
# 2024-09-23 12:37:06,677 - Processed 74000/75497 molecules.
# 2024-09-23 12:37:06,751 - Processing batch starting from index 74000...
# 2024-09-23 12:37:06,752 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 74000
# 2024-09-23 12:37:52,958 - Loaded 1000 molecules starting from index 74000
# 2024-09-23 12:39:13,722 - Processed 75000/75497 molecules.
# 2024-09-23 12:39:13,795 - Processing batch starting from index 75000...
# 2024-09-23 12:39:13,796 - Loading molecules from BKVP1_Ac_APF_v2_Ac_bridge_processed_all.sdf starting at index 75000
# 2024-09-23 12:39:58,858 - Loaded 497 molecules starting from index 75000
# 2024-09-23 12:40:53,992 - Processing complete. Output written to file.

# %%
from rdkit import Chem
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

def load_molecules(file_path):
    """Load molecules from an SDF file with their properties."""
    logging.info(f"Loading molecules from {file_path}")
    suppl = Chem.SDMolSupplier(file_path, removeHs=False)
    mols = []
    for mol in suppl:
        if mol is not None:
            mols.append(mol)
    logging.info(f"Loaded {len(mols)} molecules from {file_path}")
    return mols

def sort_molecules_by_fragment_and_sum(molecules):
    """Sort molecules by BestFragmentIndex and Sum."""
    sorted_molecules = {1: [], 2: [], 3: [], 4: []}
    for mol in molecules:
        try:
            best_fragment_index = int(mol.GetProp("BestFragmentIndex"))
            sum_value = float(mol.GetProp("Sum"))  # Assuming "Sum" is stored as a property
            sorted_molecules[best_fragment_index].append((sum_value, mol))
        except Exception as e:
            logging.warning(f"Skipping a molecule due to missing or invalid properties: {e}")

    # Sort each list by the 'Sum' value
    for index in sorted_molecules:
        sorted_molecules[index].sort(key=lambda x: x[0])

    return sorted_molecules

def reorder_and_write_molecules(sorted_molecules, output_file):
    """Reorder molecules and write them to a new SDF file in the desired order."""
    logging.info(f"Writing reordered molecules to {output_file}")
    writer = Chem.SDWriter(output_file)
    
    index = 0
    count = 0
    while True:
        added_any = False
        # Cycle through fragment indices 1, 2, 3, 4
        for fragment_index in [1, 2, 3, 4]:
            if index < len(sorted_molecules[fragment_index]):
                _, mol = sorted_molecules[fragment_index][index]
                writer.write(mol)
                count += 1
                added_any = True

        index += 1
        
        if not added_any:  # No molecules left to add
            break

    logging.info(f"Total molecules written: {count}")
    writer.close()

def main():
    # Specify file names assuming they are in the same directory as the script
    input_file = "BKVP1_with_frag_similarity.sdf"
    output_file = "BKVP1_reordered.sdf"

    # Load molecules from the input file
    molecules = load_molecules(input_file)

    # Sort molecules by BestFragmentIndex and Sum
    sorted_molecules = sort_molecules_by_fragment_and_sum(molecules)

    # Reorder molecules in 1, 2, 3, 4 sequence based on Sum and write to new file
    reorder_and_write_molecules(sorted_molecules, output_file)

    logging.info("Reordering complete.")

if __name__ == "__main__":
    main()
# Out:
# 2024-09-24 00:10:06,017 - Loading molecules from BKVP1_with_frag_similarity.sdf
# 2024-09-24 00:10:51,014 - Loaded 75497 molecules from BKVP1_with_frag_similarity.sdf
# 2024-09-24 00:10:51,206 - Writing reordered molecules to BKVP1_reordered.sdf
# 2024-09-24 00:11:33,296 - Total molecules written: 75497
# 2024-09-24 00:11:33,297 - Reordering complete.

# %%
from rdkit import Chem
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

def load_molecules(file_path):
    """Load molecules from an SDF file with their properties."""
    logging.info(f"Loading molecules from {file_path}")
    suppl = Chem.SDMolSupplier(file_path, removeHs=False)
    mols = []
    for mol in suppl:
        if mol is not None:
            mols.append(mol)
    logging.info(f"Loaded {len(mols)} molecules from {file_path}")
    return mols

def sort_molecules_by_fragment_and_similarity(molecules):
    """Sort molecules by BestFragmentIndex, prioritize MaxSimilarity (descending), then Sum (ascending)."""
    sorted_molecules = {1: [], 2: [], 3: [], 4: []}
    
    for mol in molecules:
        try:
            best_fragment_index = int(mol.GetProp("BestFragmentIndex"))
            max_similarity = float(mol.GetProp("MaxSimilarity"))  # Assuming "MaxSimilarity" is stored as a property
            sum_value = float(mol.GetProp("Sum"))  # Assuming "Sum" is stored as a property
            sorted_molecules[best_fragment_index].append((max_similarity, sum_value, mol))
        except Exception as e:
            logging.warning(f"Skipping a molecule due to missing or invalid properties: {e}")

    # Sort each list first by 'MaxSimilarity' (descending) and then by 'Sum' (ascending)
    for index in sorted_molecules:
        sorted_molecules[index].sort(key=lambda x: (-x[0], x[1]))

    return sorted_molecules

def reorder_and_write_molecules(sorted_molecules, output_file):
    """Reorder molecules and write them to a new SDF file in the desired order."""
    logging.info(f"Writing reordered molecules to {output_file}")
    writer = Chem.SDWriter(output_file)
    
    index = 0
    count = 0
    while True:
        added_any = False
        # Cycle through fragment indices 1 through 10
        for fragment_index in range(1, 5):
            if index < len(sorted_molecules[fragment_index]):
                _, _, mol = sorted_molecules[fragment_index][index]
                writer.write(mol)
                count += 1
                added_any = True

        index += 1
        
        if not added_any:  # No molecules left to add
            break

    logging.info(f"Total molecules written: {count}")
    writer.close()

def main():
    # Specify file names assuming they are in the same directory as the script
    input_file = "BKVP1_with_frag_similarity.sdf"
    output_file = "BKVP1_reordered.sdf"

    # Load molecules from the input file
    molecules = load_molecules(input_file)

    # Sort molecules by BestFragmentIndex, MaxSimilarity, and Sum
    sorted_molecules = sort_molecules_by_fragment_and_similarity(molecules)

    # Reorder molecules in 1, 2, 3, 4 sequence based on MaxSimilarity and Sum, and write to new file
    reorder_and_write_molecules(sorted_molecules, output_file)

    logging.info("Reordering complete.")

if __name__ == "__main__":
    main()
# Out:
# 2024-09-27 05:07:26,037 - Loading molecules from BKVP1_with_frag_similarity.sdf
# 2024-09-27 05:08:11,831 - Loaded 75497 molecules from BKVP1_with_frag_similarity.sdf
# 2024-09-27 05:08:12,215 - Writing reordered molecules to BKVP1_reordered.sdf
# 2024-09-27 05:08:53,458 - Total molecules written: 75497
# 2024-09-27 05:08:53,460 - Reordering complete.

# %%
from rdkit import Chem

# Function to read SDF file and return a dictionary of molecules with their identifiers
def read_sdf(file_path):
    print(f"Reading SDF file: {file_path}")
    suppl = Chem.SDMolSupplier(file_path)
    mol_dict = {}
    for mol in suppl:
        if mol is not None:
            # Create a tuple identifier from the properties
            identifier = (
                mol.GetProp('synton_id_1'), 
                mol.GetProp('synton_id_2'), 
                mol.GetProp('synton_id_3'), 
                mol.GetProp('rxn_ID'), 
                mol.GetProp('const_synth')
            )
            mol_dict[identifier] = mol
    print(f"Completed reading SDF file: {file_path}")
    return mol_dict

# Function to update structures in the fragment file with the corresponding structures from the parent file
def update_structures(fragment_file, parent_file, output_file):
    print(f"Updating structures in the fragment file '{fragment_file}' with data from '{parent_file}'...")

    # Read molecules from both SDF files
    frag_mols = read_sdf(fragment_file)
    parent_mols = read_sdf(parent_file)

    updated_mols = []

    # Replace fragment structures with parent structures if the identifier matches
    for identifier, frag_mol in frag_mols.items():
        if identifier in parent_mols:
            parent_mol = parent_mols[identifier]
            
            # Copy 'BestFragmentIndex' and 'MaxSimilarity' from frag_mol to parent_mol
            if frag_mol.HasProp("BestFragmentIndex"):
                parent_mol.SetProp("BestFragmentIndex", frag_mol.GetProp("BestFragmentIndex"))
            if frag_mol.HasProp("MaxSimilarity"):
                parent_mol.SetProp("MaxSimilarity", frag_mol.GetProp("MaxSimilarity"))

            frag_mols[identifier] = parent_mol  # Replace structure with the parent structure

    # Collect the updated molecules and ensure properties are preserved
    for identifier, mol in frag_mols.items():
        for i, prop in enumerate(['synton_id_1', 'synton_id_2', 'synton_id_3', 'rxn_ID', 'const_synth']):
            mol.SetProp(prop, identifier[i])  # Ensure the identifier properties are preserved
        updated_mols.append(mol)

    # Write the updated molecules to the new SDF file
    writer = Chem.SDWriter(output_file)
    for mol in updated_mols:
        writer.write(mol)
    writer.close()
    
    print(f"Completed updating structures. The updated SDF file is saved as: {output_file}")

# Paths to the fragment and parent SDF files
fragment_file = 'BKVP1_reordered.sdf'
parent_file = 'BKVP1_Ac_APF_v2_Ac_bridge.sdf'
output_file = 'updated_BKVP1_reordered.sdf'

# Update the structures
update_structures(fragment_file, parent_file, output_file)
# Out:
# Updating structures in the fragment file 'BKVP1_reordered.sdf' with data from 'BKVP1_Ac_APF_v2_Ac_bridge.sdf'...
# Reading SDF file: BKVP1_reordered.sdf
# Completed reading SDF file: BKVP1_reordered.sdf
# Reading SDF file: BKVP1_Ac_APF_v2_Ac_bridge.sdf
# Completed reading SDF file: BKVP1_Ac_APF_v2_Ac_bridge.sdf
# Completed updating structures. The updated SDF file is saved as: updated_BKVP1_reordered.sdf
